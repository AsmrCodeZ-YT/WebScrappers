# %%
# !pip install requests_html
# !pip install selectolax

# %%
from requests_html import HTMLSession
from selectolax.parser import HTMLParser
import csv
import matplotlib.pyplot as plt

# %%
import json
session = HTMLSession()
r = session.get(f'https://api.digikala.com/v1/categories/mouse/search/?sort=7&seo_url=%2Fcategory-mouse%2F%3Fsort%3D7&page=1')
data_json = json.loads(r.text)


for i in range(20):
    kala = data_json["data"]["products"][i]
    id = kala["id"]

# %%
# import json
comment = session.get(f'https://api.digikala.com/v1/product/2542095/comments/')
comment = json.loads(comment.text)
print(comment["data"]["pager"]["total_items"])
# Out:
# 249

# %%
question = session.get(f'https://api.digikala.com/v1/product/2542095/questions/')
question = json.loads(question.text)
question["data"]["pager"]["total_items"]
# Out:
# 205

# %%
with open('export.csv', 'w' ,encoding="utf-8") as f:
    write = csv.writer(f)
    
    for pagenumber in range(1,10):
        r = session.get(f'https://api.digikala.com/v1/categories/mouse/search/?sort=7&seo_url=%2Fcategory-mouse%2F%3Fsort%3D7&page={pagenumber}')
        data_json = json.loads(r.text)
    
        for i in range(20):
            kala = data_json["data"]["products"][i]
            id = kala["id"]
    
            name = kala["title_fa"]
            all_star = kala["data_layer"]["metric6"]
            star_rate = kala["data_layer"]["dimension9"]
            price     = kala["default_variant"]["price"]["selling_price"]


            #################### feeling good rating
            try:
                total_count = kala["default_variant"]["statistics"]["total_count"]
            except:
                total_count = None
            try:
                total_rate = kala["default_variant"]["statistics"]["total_rate"]
            except:
                total_rate = None
            #########################  link
            link = f"https://www.digikala.com/product/dkp-{id}/"
            
            #########################  count comment
            comment = session.get(f'https://api.digikala.com/v1/product/{id}/comments/')
            comment = json.loads(comment.text)
            numc    = comment["data"]["pager"]["total_items"]
            
            #########################  count question
            question = session.get(f'https://api.digikala.com/v1/product/{id}/questions/')
            question = json.loads(question.text)
            numq     = question["data"]["pager"]["total_items"]
            row = [id,name,all_star,star_rate,price,total_count,total_rate,numc,numq,link]
            write.writerow(row)

# %%
import pandas as pd 
columns = ["id","name","all_star","star_rate","price","total_count_feeling","total_rate_feeling","numc","numq","link"]

df = pd.read_csv("export.csv",names=columns)
df
# Out:
#            id                                name  all_star  star_rate  \
# 0     1792594        ماوس بی سیم تسکو مدل TM 667W      4341        4.1
# 1     1002387                  ماوس بی سیم مدل 4D      6568        3.8
# 2     4580723  ماوس مخصوص بازی اونیکوما مدل CW905       705        4.6
# 3     4250944                      ماوس مدل A2RGB       722        4.3
# 4    12143680      ماوس بی سیم بیاند مدل BM-171RF        71        4.1
# ..        ...                                 ...       ...        ...
# 175   9572000                       ماوس مدل M200        11        4.2
# 176  13085607    ماوس بی سیم گرین لاین مدل GL-113         0        0.0
# 177    323494                ماوس هترون مدل HM430        94        4.3
# 178   4064667           ماوس ای فورتک مدل N-70FXS       233        4.3
# 179   7472434         ماوس بی سیم لاجیتک مدل M350        23        4.1
#
#         price  total_count_feeling  total_rate_feeling  numc  numq  \
# 0     2980000                 77.0                86.2  3731   109
# 1     1000000                  4.0                70.0  5703   200
# 2     4290000                  5.0               100.0   989   213
# 3     2750000                 19.0                83.2   696    57
# 4     2400000                 69.0                82.4    72     8
# ..        ...                  ...                 ...   ...   ...
# 175   1350000                  NaN                 NaN    17     1
# 176   8050000                  NaN                 NaN     1     2
# 177   2150000                  NaN                 NaN    91     1
# 178   6400000                  NaN                 NaN   192     7
# 179  13300000                  2.0                90.0    18    16
#
#                                                link
# 0     https://www.digikala.com/product/dkp-1792594/
# 1     https://www.digikala.com/product/dkp-1002387/
# 2     https://www.digikala.com/product/dkp-4580723/
# 3     https://www.digikala.com/product/dkp-4250944/
# 4    https://www.digikala.com/product/dkp-12143680/
# ..                                              ...
# 175   https://www.digikala.com/product/dkp-9572000/
# 176  https://www.digikala.com/product/dkp-13085607/
# 177    https://www.digikala.com/product/dkp-323494/
# 178   https://www.digikala.com/product/dkp-4064667/
# 179   https://www.digikala.com/product/dkp-7472434/
#
# [180 rows x 10 columns]

# %%
df.describe()
# Out:
#                  id     all_star   star_rate         price  \
# count  1.800000e+02   180.000000  180.000000  1.800000e+02
# mean   5.819786e+06   352.105556    4.152778  4.756078e+06
# std    4.238311e+06   752.463897    0.483173  6.341266e+06
# min    1.895000e+03     0.000000    0.000000  6.100000e+05
# 25%    1.734467e+06    20.750000    4.075000  1.835000e+06
# 50%    6.022358e+06    83.500000    4.200000  3.005000e+06
# 75%    9.352476e+06   383.000000    4.400000  5.550000e+06
# max    1.365521e+07  6568.000000    4.900000  6.550000e+07
#
#        total_count_feeling  total_rate_feeling         numc        numq
# count           136.000000          136.000000   180.000000  180.000000
# mean             16.742647           84.667647   305.016667   19.455556
# std              25.143734           13.394642   644.410618   39.069387
# min               1.000000           20.000000     1.000000    0.000000
# 25%               3.000000           80.000000    20.000000    1.000000
# 50%               7.000000           86.300000    83.500000    5.000000
# 75%              19.000000           93.400000   302.000000   18.000000
# max             187.000000          100.000000  5703.000000  272.000000

# %%
dfe = df.copy()
dfe = dfe.dropna()

sorted_df = dfe.sort_values(by=["all_star"], ascending=False,ignore_index=True)
sorted_df["all_star"].plot()
sorted_df
# Out:
#            id                               name  all_star  star_rate  \
# 0     1002387                 ماوس بی سیم مدل 4D      6568        3.8
# 1     1792594       ماوس بی سیم تسکو مدل TM 667W      4341        4.1
# 2      158516              ماوس تسکو مدل TM2018N      4009        4.3
# 3      432631              ماوس تسکو مدل TM 264N      2126        4.1
# 4     1866048       ماوس بی سیم تسکو مدل TM 700W      2077        3.9
# ..        ...                                ...       ...        ...
# 131   8946426                 ماوس مچر مدل MR137         5        3.0
# 132  12203483  ماوس بی سیم بیاند مدل  BM-1090 RF         4        4.8
# 133   9722828                      موس مدل MS111         4        4.0
# 134  12227697            ماوس گیمینگ مدل TM 2018         4        4.5
# 135  13655210       ماوس بی سیم آر ایت مدل 03_17         1        4.0
#
#        price  total_count_feeling  total_rate_feeling  numc  numq  \
# 0    1000000                  4.0                70.0  5703   200
# 1    2980000                 77.0                86.2  3731   109
# 2    3250000                  7.0                94.2  3574   272
# 3    1770000                 42.0                87.6  1613    23
# 4    3352500                  4.0                60.0  1700   103
# ..       ...                  ...                 ...   ...   ...
# 131   798000                  3.0                73.4     5     0
# 132  1800000                  3.0                93.4     5     0
# 133  1190000                  1.0                40.0     3     1
# 134  3618900                  1.0                60.0    10     6
# 135  2880000                  1.0                80.0     2     1
#
#                                                link
# 0     https://www.digikala.com/product/dkp-1002387/
# 1     https://www.digikala.com/product/dkp-1792594/
# 2      https://www.digikala.com/product/dkp-158516/
# 3      https://www.digikala.com/product/dkp-432631/
# 4     https://www.digikala.com/product/dkp-1866048/
# ..                                              ...
# 131   https://www.digikala.com/product/dkp-8946426/
# 132  https://www.digikala.com/product/dkp-12203483/
# 133   https://www.digikala.com/product/dkp-9722828/
# 134  https://www.digikala.com/product/dkp-12227697/
# 135  https://www.digikala.com/product/dkp-13655210/
#
# [136 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   180 non-null    int64
#  1   name                 180 non-null    object
#  2   all_star             180 non-null    int64
#  3   star_rate            180 non-null    float64
#  4   price                180 non-null    int64
#  5   total_count_feeling  136 non-null    float64
#  6   total_rate_feeling   136 non-null    float64
#  7   numc                 180 non-null    int64
#  8   numq                 180 non-null    int64
#  9   link                 180 non-null    object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 14.2+ KB
